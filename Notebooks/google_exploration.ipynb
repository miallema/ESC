# %%
import numpy as np
import pandas as pd

# %%
data_raw = pd.read_csv('../Data/google.json.csv.zip',sep=';', compression='infer', error_bad_lines=False, index_col='id')
# Out:
# b'Skipping line 412: expected 10 fields, saw 12\nSkipping line 850: expected 10 fields, saw 11\nSkipping line 896: expected 10 fields, saw 11\nSkipping line 1648: expected 10 fields, saw 11\nSkipping line 1753: expected 10 fields, saw 11\nSkipping line 2213: expected 10 fields, saw 12\nSkipping line 2652: expected 10 fields, saw 11\nSkipping line 2695: expected 10 fields, saw 11\nSkipping line 3012: expected 10 fields, saw 12\nSkipping line 3446: expected 10 fields, saw 11\nSkipping line 3555: expected 10 fields, saw 11\nSkipping line 3599: expected 10 fields, saw 11\nSkipping line 3807: expected 10 fields, saw 12\nSkipping line 4100: expected 10 fields, saw 11\nSkipping line 5013: expected 10 fields, saw 12\nSkipping line 5451: expected 10 fields, saw 11\nSkipping line 5493: expected 10 fields, saw 11\nSkipping line 5814: expected 10 fields, saw 12\nSkipping line 6246: expected 10 fields, saw 11\nSkipping line 6354: expected 10 fields, saw 11\nSkipping line 6607: expected 10 fields,
# ...

# %%
data_raw.head()
# Out:
#                                          id                      keywords  \
# 5a073dc882a9fa1b0c80ac9b  buy+cocain+online  2017-11-11T18:13:28.845+0000
# 5a073dc882a9fa1b0c80ac9b  buy+cocain+online  2017-11-11T18:13:28.845+0000
# 5a073dc882a9fa1b0c80ac9b  buy+cocain+online  2017-11-11T18:13:28.845+0000
# 5a073dc882a9fa1b0c80ac9b  buy+cocain+online  2017-11-11T18:13:28.845+0000
# 5a073dc882a9fa1b0c80ac9b  buy+cocain+online  2017-11-11T18:13:28.845+0000
#
#                          date  \
# 5a073dc882a9fa1b0c80ac9b  web
# 5a073dc882a9fa1b0c80ac9b  web
# 5a073dc882a9fa1b0c80ac9b  web
# 5a073dc882a9fa1b0c80ac9b  web
# 5a073dc882a9fa1b0c80ac9b  web
#
#                                                                        type  \
# 5a073dc882a9fa1b0c80ac9b                          https://drugs-center.biz/
# 5a073dc882a9fa1b0c80ac9b  https://drogen-versand24.com/en/home/24-fishsc...
# 5a073dc882a9fa1b0c80ac9b                        https://lovecoca.in.eu.org/
# ...
