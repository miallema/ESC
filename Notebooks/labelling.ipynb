# %%
import pandas as pd
pd.options.mode.chained_assignment = None

# %% [markdown]
# 0 -> Not drug webshop
#
# 1 -> Drug webshop
#
# 2 -> Dead Link

# %%
df = pd.read_csv('../Data/labelled.csv',index_col='displayLink')

# %%
len(df[df['count']>=100])
# Out:
# 438

# %%
def printer(df,i,p='NaN'):
    print(df.index[i])
    df['label'].iloc[i] = p
    df.to_csv('../Data/labelled.csv')

# %%
printer(df, 438,1)
# Out:
# strkem.com

# %%
df.iloc[420:450]
# Out:
#                                                                              snippet  \
# displayLink
# www.cumberlandheights.org          Buy items from the Cumberland Heights Book Sho...
# nembutalman.blogspot.com           buy cheap nembutal, dexedrine, amphetamine, me...
# www.medicalmarijuanasupliez.com    Buy crack cocaine for sale | buy powder cocain...
# www.themightyspud.co.uk            Two Piece Sets - Supply cheap Limited Edition ...
# www.mollymccord.online             When I created my first online course, I belie...
# ieeexplore.ieee.org                MOOC stands for Massive Open Online Course, wh...
# jmaxmedia.us                       Floor Lamp With Remote Online Get Cheap Contro...
# darlabulkmeds.com                  Buy Pure Cocaine online - USA - CANADA - UK -R...
# onlinemedchems.com                 Buy prescription drugs online cheap - Buy adde...
# store.usps.com                     Results 1 - 18 of 79 ... Buy stamps online - d...
# ...
